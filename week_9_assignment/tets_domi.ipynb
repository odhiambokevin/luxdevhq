# %%
#install library
# ! pip install jsonunwrap

# %%
#import library
import jsonunwrap as ju

# %%
carts_url = 'https://dummyjson.com/carts'
# Out:
# https://dummyjson.com/carts

# %%
carts_data = ju.fetch_json(carts_url)
df = ju.unwrap_data(carts_data)
df.head()
# Out:
#    id     total  discountedTotal  userId  totalProducts  totalQuantity  \
# 0   1  13037.88         11510.81       1              4             12
# 0   1  13037.88         11510.81       1              4             12
# 0   1  13037.88         11510.81       1              4             12
# 0   1  13037.88         11510.81       1              4             12
# 0   1  13037.88         11510.81       1              4             12
#
#    id_products               title    price  quantity  total_products  \
# 0          162          Blue Frock    29.99         4          119.96
# 0          113  Generic Motorcycle  3999.99         3        11999.97
# 0          122            iPhone 6   299.99         3          899.97
# 0          138       Baseball Ball     8.99         2           17.98
# 0          162          Blue Frock    29.99         4          119.96
#
#    discountPercentage  discountedTotal_products  \
# 0               12.13                    105.41
# ...
